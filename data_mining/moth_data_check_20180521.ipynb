# %%
# %matplotlib inline

import numpy as np
import pandas as pd 
import pandas_profiling 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 資料確認
#
# 想要知道的問題：
#
# 1. 各資料欄位定義與屬性
# 2. 各資料欄位的筆數
# 3. 各欄位缺失值狀況
# 4. 各資料欄位的分布
# 5. 沿海拔各型值的變化 (總體、物種)
# 6. 三型值的相關性

# %%
df  = pd.read_csv('E:/2015TT&RS_SW_final20180517.csv', encoding='big5')
df.columns
# Out:
# Index(['Specimen No.', 'Family', 'Code', 'Species', 'Altitude', 'W_length',
#        'B_length', 'Weight', 'Weight_with_pin', 'Weight_pin', 'No.',
#        'Coll_data', 'Coll_date', 'Sex', 'dissected', 'Note', 'Non-sampled',
#        '補籤', '跳籤', 'Photo', 'ASIZHX_code', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Species.1'],
#       dtype='object')

# %%
df_Note = pd.read_csv('E:/origin_data/species_data/moth/moth_ecological_data_from_googlesheet.csv', encoding='big5')
df_Note.columns
# Out:
# Index(['Specimen No.', 'Wing length (mm)', 'Body length (mm)', 'Weight',
#        'Weight(ori)', '針重', '針序號', 'Pin_type', 'Note', '建檔者（ C/W/H ）',
#        '形質測量建檔日期', 'Sex', 'Coll_data', 'Coll_date', 'Note2', 'Family',
#        'Accepted_code', 'Photo', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (12539, 28)

# %% [markdown]
# 1. 各欄位名稱 ( 'Specimen No.', 'Family', 'Code', 'Species', 'Altitude', 'W_length',
#                           'B_length', 'Weight', 'Weight_with_pin', 'Weight_pin', 'No.',
#                          'Coll_data', 'Coll_date', 'Sex', 'dissected', 'Note', 'Non-sampled',
#                          '補籤', '跳籤', 'Photo', 'ASIZHX_code')
#
# 2. 總共幾欄 ( total : 28, selected to analysis : 21)

# %%
df_selected = df.loc[ : , ['Specimen No.', 'Family', 'Species', 'Altitude', 'W_length','B_length', 'Weight', 'Weight_with_pin', 'Weight_pin','Coll_data', 'Coll_date', 'Note']]

df_selected.head(5)
# Out:
#    Specimen No.       Family                 Species  Altitude  W_length  \
# 0  ASIZHX121668    Crambidae            Agrotera sp.       343      0.00
# 1  ASIZHX121669    Crambidae            Agrotera sp.       343      0.00
# 2  ASIZHX121516  Geometridae   Amblychia angeronaria       343     42.05
# 3  ASIZHX121593   Sphingidae  Ambulyx kuangtungensis       343     33.40
# 4  ASIZHX121756    Noctuidae        Apsarasa radians       343     22.17
#
#    B_length  Weight  Weight_with_pin  Weight_pin Coll_data Coll_date   Note
# 0      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 1      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 2     24.45  0.0000           0.0000       0.000   MCE0250  20180720    NaN
# 3     29.02  0.1226           0.1686       0.046   MCE0250  20180721    NaN
# 4     19.45  0.0000           0.0000       0.000   MCE0250  20180722    NaN

# %%
df_Note_selected = df_Note.loc[:, ['Specimen No.', 'Note']]
# df_Note_selected[df_Note_selected['Specimen No.'] == 'ASIZHX113862' ]

# %%
# print( df_selected.shape, df_Note_selected.shape, df_merge.shape)

# %%
# df_selected.to_csv('E:/df_select.csv')
# df_Note_selected.to_csv('E:/df_Note_selected.csv')
# df_merge.to_csv('E:/df_merge.csv')

# %%
df_merge = pd.merge(df_selected, df_Note_selected, how='left', left_on= 'Specimen No.', right_on='Specimen No.')
df_merge.head(5)
# Out:
#    Specimen No.       Family                 Species  Altitude  W_length  \
# 0  ASIZHX121668    Crambidae            Agrotera sp.       343      0.00
# 1  ASIZHX121669    Crambidae            Agrotera sp.       343      0.00
# 2  ASIZHX121516  Geometridae   Amblychia angeronaria       343     42.05
# 3  ASIZHX121593   Sphingidae  Ambulyx kuangtungensis       343     33.40
# 4  ASIZHX121756    Noctuidae        Apsarasa radians       343     22.17
#
#    B_length  Weight  Weight_with_pin  Weight_pin Coll_data Coll_date Note_x  \
# 0      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 1      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 2     24.45  0.0000           0.0000       0.000   MCE0250  20180720    NaN
# 3     29.02  0.1226           0.1686       0.046   MCE0250  20180721    NaN
# 4     19.45  0.0000           0.0000       0.000   MCE0250  20180722    NaN
#
#                  Note_y
# 0              僅做紀錄未測量。
# 1              僅做紀錄未測量。
# 2  前後翅均破損、標本缺損。僅做紀錄未測量。
# 3                   NaN
# 4            前翅破損、標本缺損。

# %%
df_selected.Species.isnull().sum()
# Out:
# 2502

# %% [markdown]
# ###  整體資料狀況 不做任何處置

# %%
# pandas_profiling.ProfileReport(df_selected)

# %% [markdown]
# ## 需要大蛾與小蛾科的大表
# #### 已解決
# #### Note有 micro / micromoth 除外，其他都是大蛾

# %%
# df_merge.columns
# df_merge.groupby('Note_x').size()

# %%
df_merge['B_length'].apply(lambda x:float(x))
df_merge['W_length'].apply(lambda x:float(x))
df_merge['Weight'].apply(lambda x:float(x))
df_merge['Weight_pin'].apply(lambda x:float(x))
df_merge['Weight_with_pin'].apply(lambda x:float(x))
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.1686
# 4        0.0000
# 5        0.0000
# 6        0.1286
# 7        0.1215
# 8        0.0000
# 9        0.0000
# 10       0.0000
# 11       0.0000
# 12       0.0000
# 13       0.0000
# 14       0.0000
# 15       0.0000
# 16       0.0000
# 17       0.0000
# 18       0.0000
# 19       0.0832
# 20       0.0000
# 21       0.0000
# 22       0.0000
# 23       0.0000
# 24       0.0000
# 25       0.0642
# 26       0.0000
# 27       0.0000
# 28       0.0000
# 29       0.0000
#           ...
# 12535    0.0800
# 12536    0.0900
# 12537    0.0900
# 12538    0.0700
# 12539    0.0800
# 12540    0.0700
# 12541    0.0600
# 12542    0.0700
# 12543    0.0600
# 12544    0.0500
# 12545    0.0900
# 12546    0.0700
# 12547    0.0600
# 12548    0.0600
# 12549    0.0800
# 12550    0.0600
# 12551    0.0700
# 12552    0.0600
# 12553    0.0600
# 12554    0.0700
# 12555    0.0600
# 12556    0.0600
# 12557    0.0400
# 12558    0.0600
# 12559    0.2800
# 12560    0.2700
# 12561    0.2900
# 12562    0.2800
# 12563    0.1600
# 12564    0.1700
# Name: Weight_with_pin, Length: 12565, dtype: float64

# %% [markdown]
# ## 大蛾與小蛾科的問題
# ### Note有 micro / micromoth 除外，其他都是大蛾

# %%
def macro_micro_comfirm(datatable, column, new_column_name):
    new_column = []
    for value in datatable[column]:
        if value == 'MICRO' or value == 'Micro' or value == 'Micromoth':
            new_column.append('Micro')
        else:
            new_column.append('Macro')
    datatable[new_column_name] = new_column

# %%
macro_micro_comfirm(df_merge, 'Note_x', 'New_column')

# %%
df_merge.head(5)
# Out:
#    Specimen No.       Family                 Species  Altitude  W_length  \
# 0  ASIZHX121668    Crambidae            Agrotera sp.       343      0.00
# 1  ASIZHX121669    Crambidae            Agrotera sp.       343      0.00
# 2  ASIZHX121516  Geometridae   Amblychia angeronaria       343     42.05
# 3  ASIZHX121593   Sphingidae  Ambulyx kuangtungensis       343     33.40
# 4  ASIZHX121756    Noctuidae        Apsarasa radians       343     22.17
#
#    B_length  Weight  Weight_with_pin  Weight_pin Coll_data Coll_date Note_x  \
# 0      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 1      0.00  0.0000           0.0000       0.000   MCE0250  20180721  Micro
# 2     24.45  0.0000           0.0000       0.000   MCE0250  20180720    NaN
# 3     29.02  0.1226           0.1686       0.046   MCE0250  20180721    NaN
# 4     19.45  0.0000           0.0000       0.000   MCE0250  20180722    NaN
#
#                  Note_y New_column
# 0              僅做紀錄未測量。      Micro
# 1              僅做紀錄未測量。      Micro
# 2  前後翅均破損、標本缺損。僅做紀錄未測量。      Macro
# 3                   NaN      Macro
# 4            前翅破損、標本缺損。      Macro

# %% [markdown]
# ## 篩選Macro moth

# %%
df_macro = df_merge.loc[df_merge['New_column'] =='Macro']

# %%
# df_macro.New_column.count()
# Out:
# 8433

# %% [markdown]
# ## 排除三型直接未測量的資料

# %%
df_macro_mt = df_macro.loc[(df_macro['B_length'] >0)  & (df_macro['W_length'] >0) & (df_macro['Weight_with_pin'] >0) ]

# %%
df_macro_mt.loc[(df_macro_mt['Weight'] ==0)]
# Out:
#        Specimen No.       Family                  Species  Altitude  W_length  \
# 5979   ASIZHX116509     Erebidae          Nudaria ranruna      1511     10.11
# 5987   ASIZHX116708     Erebidae          Nudaria ranruna      1511      9.95
# 6922   ASIZHX114302  Geometridae   Alcis taiwanovariegata      1734     15.95
# 7449   ASIZHX114574  Geometridae      Harutalcis fumigata      1734     19.94
# 8352   ASIZHX114505     Erebidae  Plecoptera siderogramma      1734     12.38
# 9057   ASIZHX112007  Geometridae        Abraxas tenellula      2039     18.81
# 9069   ASIZHX112019  Geometridae        Abraxas tenellula      2039     19.73
# 11445  ASIZHX110882     Erebidae         Euproctis sparsa      2421     15.44
# 11511  ASIZHX111056     Erebidae              Ghoria bani      2421     17.27
#
#        B_length  Weight  Weight_with_pin  Weight_pin Coll_data Coll_date  \
# 5979       7.21     0.0            0.047       0.047   MCE1500  20150722
# 5987       6.39     0.0            0.047       0.047   MCE1500  20150722
# 6922      13.87     0.0            0.047       0.047   MCE1750  20150723
# 7449      16.58     0.0            0.047       0.047   MCE1750  20150723
# 8352       9.39     0.0            0.047       0.047   MCE1750  20150723
# 9057      13.51     0.0            0.047       0.047   MCE2000  20150720
# 9069      12.70     0.0            0.047       0.047   MCE2000  20150720
# 11445     10.84     0.0            0.047       0.047   MCE2500  20150722
# 11511     13.24     0.0            0.047       0.047   MCE2500  20150722
#
#       Note_x Note_y New_column
# 5979     NaN    NaN      Macro
# 5987     NaN    NaN      Macro
# 6922     NaN    NaN      Macro
# 7449     NaN    NaN      Macro
# 8352     NaN    NaN      Macro
# 9057     NaN    NaN      Macro
# 9069     NaN    NaN      Macro
# 11445    NaN    NaN      Macro
# 11511    NaN    NaN      Macro

# %%
# df_macro_mt.shape
# Out:
# (5903, 14)

# %% [markdown]
# ### Specimen No. missing 2

# %%
df_macro_mt[df_macro_mt['Specimen No.'].isnull()] # the reslut of merge seem to error
# Out:
# Empty DataFrame
# Columns: [Specimen No., Family, Species, Altitude, W_length, B_length, Weight, Weight_with_pin, Weight_pin, Coll_data, Coll_date, Note_x, Note_y, New_column]
# Index: []

# %% [markdown]
# ### Family | missing 6 (check if no problem, we can update these 6 data)

# %%
df_macro_mt[df_macro_mt.Family.isnull()]
# Out:
#       Specimen No. Family Species  Altitude  W_length  B_length  Weight  \
# 8996  ASIZHX115075    NaN     NaN      1734      9.51      8.12 -0.0081
# 8997  ASIZHX115076    NaN     NaN      1734      9.49      7.40 -0.0083
# 8998  ASIZHX115077    NaN     NaN      1734      8.15      6.91 -0.0086
# 8999  ASIZHX115078    NaN     NaN      1734      9.42      7.28 -0.0074
# 9000  ASIZHX115079    NaN     NaN      1734      9.12      6.60 -0.0096
# 9001  ASIZHX115080    NaN     NaN      1734      9.04      7.19 -0.0081
#
#       Weight_with_pin  Weight_pin Coll_data Coll_date Note_x Note_y New_column
# 8996           0.0389       0.047   MCE1750  20150724    NaN    NaN      Macro
# 8997           0.0387       0.047   MCE1750  20150724    NaN    NaN      Macro
# 8998           0.0384       0.047   MCE1750  20150724    NaN    NaN      Macro
# 8999           0.0396       0.047   MCE1750  20150724    NaN    NaN      Macro
# 9000           0.0374       0.047   MCE1750  20150724    NaN    NaN      Macro
# 9001           0.0389       0.047   MCE1750  20150724    NaN    NaN      Macro

# %% [markdown]
# ### Species missing 35  (check if no problem, we can update these 35 data)

# %%
df_macro_mt[df_macro_mt.Species.isnull()]
# speceis NaN  is micromoth
# Out:
#        Specimen No.       Family Species  Altitude  W_length  B_length  \
# 1316   ASIZHX121085     Erebidae     NaN       544      9.26      8.14
# 1317   ASIZHX121092     Erebidae     NaN       544      6.33      5.21
# 1319   ASIZHX121096     Erebidae     NaN       544      7.66      7.04
# 1325   ASIZHX122410     Erebidae     NaN       544     20.00     18.00
# 2188   ASIZHX119943     Erebidae     NaN       876      9.03      7.87
# 2194   ASIZHX120156     Erebidae     NaN       876     11.25      8.43
# 2196   ASIZHX120160     Erebidae     NaN       876      6.20      4.50
# 2199   ASIZHX120553  Geometridae     NaN       876     10.50      7.51
# 2201   ASIZHX119843      Nolidae     NaN       876      5.40      4.59
# 2202   ASIZHX119844      Nolidae     NaN       876      7.62      7.35
# 2203   ASIZHX119845      Nolidae     NaN       876      6.16      3.79
# 2204   ASIZHX119847      Nolidae     NaN       876      5.34      4.28
# 2208   ASIZHX120157      Nolidae     NaN       876      9.95      7.53
# 2210   ASIZHX120258      Nolidae     NaN       876      6.33      5.73
# 2211   ASIZHX120259      Nolidae     NaN       876      7.44      6.48
# 4630   ASIZHX117540     Erebidae     NaN      1255     15.28     11.69
# 4823   ASIZHX117548     Erebidae     NaN      1255     10.90     10.03
# 4824   ASIZHX117549     Erebidae     NaN      1255     11.42      9.09
# 4825   ASIZHX117550     Erebidae     NaN      1255     11.42      9.69
# 4827   ASIZHX117552     Erebidae     NaN      1255     10.57      7.00
# 4829   ASIZHX117554     Erebidae     NaN      1255     10.86      7.64
# 4831   ASIZHX117559     Erebidae     NaN      1255      9.75      8.15
# 4832   ASIZHX117560     Erebidae     NaN      1255      9.11      7.09
# 4833   ASIZHX117561     Erebidae     NaN      1255      8.95      6.25
# 8992   ASIZHX113898     Erebidae     NaN      1734     13.82     11.22
# 8993   ASIZHX113899     Erebidae     NaN      1734     14.80     12.49
# 8994   ASIZHX113900     Erebidae     NaN      1734     14.11     11.66
# 8995   ASIZHX114498  Hesperiidae     NaN      1734     18.64     17.71
# 8996   ASIZHX115075          NaN     NaN      1734      9.51      8.12
# 8997   ASIZHX115076          NaN     NaN      1734      9.49      7.40
# 8998   ASIZHX115077          NaN     NaN      1734      8.15      6.91
# 8999   ASIZHX115078          NaN     NaN      1734      9.42      7.28
# 9000   ASIZHX115079          NaN     NaN      1734      9.12      6.60
# 9001   ASIZHX115080          NaN     NaN      1734      9.04      7.19
# 11226  ASIZHX111422     Erebidae     NaN      2350      8.35      6.89
#
#        Weight  Weight_with_pin  Weight_pin Coll_data Coll_date  \
# 1316   0.0138           0.0418       0.028   MCE0500  20150721
# 1317   0.0138           0.0418       0.028   MCE0500  20150721
# 1319   0.0134           0.0414       0.028   MCE0500  20150721
# 1325   0.0292           0.0752       0.046   MCE0500  20150720
# 2188   0.0044           0.0504       0.046   MCE0750  20150721
# 2194  -0.0156           0.0434       0.059   MCE0750  20150722
# 2196   0.0119           0.0399       0.028   MCE0750  20150722
# 2199  -0.0171           0.0419       0.059   MCE0750  20150720
# 2201   0.0116           0.0396       0.028   MCE0750  20150720
# 2202   0.0131           0.0411       0.028   MCE0750  20150720
# 2203   0.0121           0.0401       0.028   MCE0750  20150720
# 2204   0.0118           0.0398       0.028   MCE0750  20150720
# 2208   0.0160           0.0440       0.028   MCE0750  20150722
# 2210   0.0128           0.0408       0.028   MCE0750  20150722
# 2211   0.0133           0.0413       0.028   MCE0750  20150722
# 4630   0.0585           0.0775       0.019   MCE1250  20150722
# 4823   0.0454           0.0644       0.019   MCE1250  20150722
# 4824   0.0140           0.0420       0.028   MCE1250  20150722
# 4825   0.0446           0.0636       0.019   MCE1250  20150722
# 4827   0.0129           0.0409       0.028   MCE1250  20150722
# 4829   0.0429           0.0619       0.019   MCE1250  20150722
# 4831   0.0155           0.0435       0.028   MCE1250  20150722
# 4832   0.0134           0.0414       0.028   MCE1250  20150722
# 4833   0.0434           0.0624       0.019   MCE1250  20150722
# 8992   0.0080           0.0540       0.046   MCE1750  20150722
# 8993   0.0185           0.0645       0.046   MCE1750  20150722
# 8994   0.0111           0.0571       0.046   MCE1750  20150722
# 8995   0.0240           0.0710       0.047   MCE1750  20150723
# 8996  -0.0081           0.0389       0.047   MCE1750  20150724
# 8997  -0.0083           0.0387       0.047   MCE1750  20150724
# 8998  -0.0086           0.0384       0.047   MCE1750  20150724
# 8999  -0.0074           0.0396       0.047   MCE1750  20150724
# 9000  -0.0096           0.0374       0.047   MCE1750  20150724
# 9001  -0.0081           0.0389       0.047   MCE1750  20150724
# 11226  0.0116           0.0396       0.028   MCE2250  20150722
#
#                          Note_x Note_y New_column
# 1316                        NaN    NaN      Macro
# 1317                        NaN    NaN      Macro
# 1319                        NaN    NaN      Macro
# 1325                        NaN    NaN      Macro
# 2188                        NaN    NaN      Macro
# 2194                        NaN    NaN      Macro
# 2196                        NaN    NaN      Macro
# 2199                        NaN    NaN      Macro
# 2201                        NaN    NaN      Macro
# 2202                        NaN    NaN      Macro
# 2203                        NaN    NaN      Macro
# 2204                        NaN    NaN      Macro
# 2208                        NaN    NaN      Macro
# 2210                        NaN    NaN      Macro
# 2211                        NaN    NaN      Macro
# 4630                  destroyed    NaN      Macro
# 4823                        NaN    NaN      Macro
# 4824                        NaN    NaN      Macro
# 4825                        NaN    NaN      Macro
# 4827                        NaN    NaN      Macro
# 4829                        NaN    NaN      Macro
# 4831                        NaN    NaN      Macro
# 4832                        NaN    NaN      Macro
# 4833                        NaN    NaN      Macro
# 8992                        NaN    NaN      Macro
# 8993                        NaN    NaN      Macro
# 8994                        NaN    NaN      Macro
# 8995                        NaN    NaN      Macro
# 8996                        NaN    NaN      Macro
# 8997                        NaN    NaN      Macro
# 8998                        NaN    NaN      Macro
# 8999                        NaN    NaN      Macro
# 9000                        NaN    NaN      Macro
# 9001                        NaN    NaN      Macro
# 11226  should be checked, small    NaN      Macro

# %% [markdown]
# ### 整理後資料整體概況

# %%
pandas_profiling.ProfileReport(df_macro_mt)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>5903 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>13.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>691.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>120.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Altitude"><code>Altitude</code></a> is highly correlated with <a href="#pp_var_index"><code>index</code></a> (ρ = 0.96602) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_B_length"><code>B_length</code></a> is highly correlated with <a href="#pp_var_W_length"><code>W_length</code></a> (ρ = 0.926) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_New_column"><code>New_column</code></a> has constant value Macro <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Note_x"><code>Note_x</code></a> has 5754 / 97.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Note_y"><code>Note_y</code></a> has 5892 / 99.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Species"><code>Species</code></a> has a high cardinality: 745 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Weight"><code>Weight</code></a> is highly skewed (γ1 = 66.955)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_Weight_with_pin"><code>Weight_with_pin</code></a> is highly correlated with <a href="#pp_var_Weight"><code

# %% [markdown]
# ## 針重量分布(100根)

# %%
df_pin = pd.read_excel(io='E:/origin_data/species_data/moth/moth_pin_weight_Sichuan.xlsx', sheetname='針重')

# %%
df_pin = df_pin[0:100]
# df_pin.columns
df_pin.sort_values(by=['pin_weight'], ascending=True).head()
# Out:
#     pin_number  pin_weight  pin_type
# 14          15      0.0351         1
# 50          51      0.0353         1
# 83          84      0.0354         1
# 53          54      0.0354         1
# 15          16      0.0358         1

# %%
plt.hist(sorted(df_pin['pin_weight']))
mean = sum(df_pin['pin_weight'])/len(df_pin['pin_weight'])

plt.plot([mean, mean], [0, 25])

# %%
box_plot = df_pin.boxplot(column='pin_weight')
# plt.boxplot(df_pin['pin_weight'])

# variance of weight seems not so large in 100 pin sameple

# %% [markdown]
# ### Go back to review weight data

# %%
df_selected[df_selected['Weight'] ==0 & df_selected.Note.notnull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-63c5341a9d43> in <module>()
# ----> 1 df_selected[df_selected['Weight'] ==0 & df_selected.Note.notnull()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Note'
